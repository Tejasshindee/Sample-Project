# %%
import pandas as pd

# Replace 'file.xlsx' with the path to your Excel file
# df = pd.read_excel('purchase_2.xlsx')
df = pd.read_csv('purchase1.csv')



# Display the first 10 rows of the dataframe
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e6ea249a9055> in <cell line: 5>()
#       3 # Replace 'file.xlsx' with the path to your Excel file
#       4 # df = pd.read_excel('purchase_2.xlsx')
# ----> 5 df = pd.read_csv('purchase1.csv')
#       6
#       7
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
df.dtypes
# Out:
# event_time        object
# order_id         float64
# product_id       float64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# dtype: object

# %%
pd.set_option('display.float_format', lambda x: '%.f' % x)

# %%
print(df.head(5))
# Out:
#                 event_time            order_id          product_id  \
# 0  2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 1  2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2  2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 3  2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4  2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
#
#           category_id                category_code    brand  price  \
# 0 2268110000000000000           electronics.tablet  samsung    162
# 1 2268110000000000000           electronics.tablet  samsung    162
# 2 2268110000000000000  electronics.audio.headphone   huawei     78
# 3 2268110000000000000  electronics.audio.headphone   huawei     78
# 4 2268110000000000000                          NaN  karcher    218
#
#               user_id
# 0 1515920000000000000
# 1 1515920000000000000
# 2 1515920000000000000
# 3 1515920000000000000
# 4 1515920000000000000

# %%
df.drop_duplicates()
# Out:
#                      event_time            order_id          product_id  \
# 0       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# 5       2020-04-26 08:45:57 UTC 2295720000000000000 1515970000000000000
# 6       2020-04-26 09:33:47 UTC 2295740000000000000 1515970000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                category_code     brand  price  \
# ...

# %%
df
# Out:
#                      event_time            order_id          product_id  \
# 0       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 1       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 3       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                category_code     brand  price  \
# ...

# %%
df.drop_duplicates(subset=['event_time','order_id'], keep=False)
# Out:
#                      event_time            order_id          product_id  \
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# 5       2020-04-26 08:45:57 UTC 2295720000000000000 1515970000000000000
# 10      2020-04-26 14:55:26 UTC 2295900000000000000 2273950000000000000
# 11      2020-04-26 23:35:39 UTC 2296160000000000000 1515970000000000000
# 12      2020-04-27 07:24:51 UTC 2296400000000000000 2273950000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                     category_code     brand  price  \
# ...

# %%
df.drop_duplicates(subset=['event_time','order_id'])
# Out:
#                      event_time            order_id          product_id  \
# 0       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# 5       2020-04-26 08:45:57 UTC 2295720000000000000 1515970000000000000
# 6       2020-04-26 09:33:47 UTC 2295740000000000000 1515970000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                category_code     brand  price  \
# ...

# %%
df.drop_duplicates(subset=['event_time','order_id'], keep=False)
# Out:
#                      event_time            order_id          product_id  \
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# 5       2020-04-26 08:45:57 UTC 2295720000000000000 1515970000000000000
# 10      2020-04-26 14:55:26 UTC 2295900000000000000 2273950000000000000
# 11      2020-04-26 23:35:39 UTC 2296160000000000000 1515970000000000000
# 12      2020-04-27 07:24:51 UTC 2296400000000000000 2273950000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                     category_code     brand  price  \
# ...

# %%
df.drop_duplicates(subset=['event_time','order_id','product_id', 'category_id','category_code'])
# Out:
#                      event_time            order_id          product_id  \
# 0       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# 5       2020-04-26 08:45:57 UTC 2295720000000000000 1515970000000000000
# 6       2020-04-26 09:33:47 UTC 2295740000000000000 1515970000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                category_code     brand  price  \
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 135734    False
# 135735    False
# 135736    False
# 135737    False
# 135738    False
# Length: 135739, dtype: bool

# %%
df
# Out:
#                      event_time            order_id          product_id  \
# 0       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 1       2020-04-24 11:50:39 UTC 2294360000000000000 1515970000000000000
# 2       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 3       2020-04-24 14:37:43 UTC 2294440000000000000 2273950000000000000
# 4       2020-04-24 19:16:21 UTC 2294580000000000000 2273950000000000000
# ...                         ...                 ...                 ...
# 135734  2020-01-12 05:19:23 UTC 2348770000000000000 1515970000000000000
# 135735  2020-01-12 07:39:54 UTC 2348770000000000000 2273950000000000000
# 135736  2020-01-11 06:19:11 UTC 2348770000000000000 1515970000000000000
# 135737  2020-01-12 07:43:33 UTC 2348770000000000000 1515970000000000000
# 135738             2020-01-12 0                 NaN                 NaN
#
#                category_id                category_code     brand  price  \
# ...

# %% [markdown]
# # **Splitting files**

# %%
import pandas as pd

# read DataFrame
data = pd.read_csv("purchase1.csv")

# no of csv files with row size
k = 5
size = 210000

for i in range(k):
	df = data[size*i:size*(i+1)]
	df.to_csv(f'purchase_split_{i+1}.csv', index=False)

# %%
df_1 = pd.read_csv("purchase_split_1.csv")
print(df_1)
# Out:
#                      event_time             order_id           product_id  \
# 0       2020-04-24 11:50:39 UTC  2294360000000000000  1515970000000000000
# 1       2020-04-24 11:50:39 UTC  2294360000000000000  1515970000000000000
# 2       2020-04-24 14:37:43 UTC  2294440000000000000  2273950000000000000
# 3       2020-04-24 14:37:43 UTC  2294440000000000000  2273950000000000000
# 4       2020-04-24 19:16:21 UTC  2294580000000000000  2273950000000000000
# ...                         ...                  ...                  ...
# 209995  2020-01-19 10:20:33 UTC  2348780000000000000  1515970000000000000
# 209996  2020-01-20 10:31:53 UTC  2348780000000000000  2273950000000000000
# 209997  2020-01-20 10:31:53 UTC  2348780000000000000  1515970000000000000
# 209998  2020-01-18 09:34:03 UTC  2348780000000000000  1515970000000000000
# 209999  2020-01-18 07:51:25 UTC  2348780000000000000  1515970000000000000
#
#                category_id                     category_code      brand  \
# ...

# %%
df_2 = pd.read_csv("purchase_split_2.csv")
print(df_2)
# Out:
#                      event_time             order_id           product_id  \
# 0       2020-01-19 06:06:00 UTC  2348780000000000000  1515970000000000000
# 1       2020-01-20 13:03:51 UTC  2348780000000000000  1515970000000000000
# 2       2020-01-19 07:38:52 UTC  2348780000000000000  1515970000000000000
# 3       2020-01-19 07:38:52 UTC  2348780000000000000  1515970000000000000
# 4       2020-01-19 07:38:52 UTC  2348780000000000000  2273950000000000000
# ...                         ...                  ...                  ...
# 209995  2020-02-09 10:11:24 UTC  2348790000000000000  2273950000000000000
# 209996  2020-02-09 10:11:24 UTC  2348790000000000000  1515970000000000000
# 209997  2020-02-08 15:24:05 UTC  2348790000000000000  1515970000000000000
# 209998  2020-02-08 12:27:45 UTC  2348790000000000000  1515970000000000000
# 209999  2020-02-09 08:00:41 UTC  2348790000000000000  1515970000000000000
#
#                category_id                category_code    brand  price  \
# ...

# %%
df_3 = pd.read_csv("purchase_split_3.csv")
print(df_3)
# Out:
#                      event_time             order_id           product_id  \
# 0       2020-02-09 08:00:41 UTC  2348790000000000000  1515970000000000000
# 1       2020-02-08 15:56:27 UTC  2348790000000000000  1515970000000000000
# 2       2020-02-08 15:56:27 UTC  2348790000000000000  1515970000000000000
# 3       2020-02-08 15:56:27 UTC  2348790000000000000  1515970000000000000
# 4       2020-02-09 11:44:23 UTC  2348790000000000000  1515970000000000000
# ...                         ...                  ...                  ...
# 209995  2020-02-28 12:20:29 UTC  2348810000000000000  1515970000000000000
# 209996  2020-02-28 04:11:16 UTC  2348810000000000000  1515970000000000000
# 209997  2020-02-28 12:35:50 UTC  2348810000000000000  1515970000000000000
# 209998  2020-02-28 14:02:23 UTC  2348810000000000000  1515970000000000000
# 209999  2020-02-28 07:55:42 UTC  2348810000000000000  1515970000000000000
#
#                category_id                     category_code      brand  \
# ...

# %%
df_4 = pd.read_csv("purchase_split_4.csv")
print(df_4)
# Out:
#                      event_time             order_id           product_id  \
# 0       2020-02-28 16:48:25 UTC  2348810000000000000  1515970000000000000
# 1       2020-02-28 16:48:25 UTC  2348810000000000000  1515970000000000000
# 2       2020-02-28 16:48:25 UTC  2348810000000000000  1515970000000000000
# 3       2020-02-28 16:48:25 UTC  2348810000000000000  2273950000000000000
# 4       2020-02-28 16:48:25 UTC  2348810000000000000  1515970000000000000
# ...                         ...                  ...                  ...
# 209995  2020-03-16 04:55:18 UTC  2348820000000000000  1515970000000000000
# 209996  2020-03-17 07:09:23 UTC  2348820000000000000  1515970000000000000
# 209997  2020-03-17 07:09:23 UTC  2348820000000000000  1515970000000000000
# 209998  2020-03-17 07:09:23 UTC  2348820000000000000  1515970000000000000
# 209999  2020-03-15 07:28:05 UTC  2348820000000000000  1515970000000000000
#
#                category_id               category_code     brand  price  \
# ...

# %%
df_5 = pd.read_csv("purchase_split_5.csv")
print(df_5)
# Out:
#                      event_time             order_id           product_id  \
# 0       2020-03-15 07:28:05 UTC  2348820000000000000  1515970000000000000
# 1       2020-03-15 07:28:05 UTC  2348820000000000000  1515970000000000000
# 2       2020-03-17 10:13:02 UTC  2348820000000000000  1515970000000000000
# 3       2020-03-16 10:28:59 UTC  2348820000000000000  2273950000000000000
# 4       2020-03-16 10:28:59 UTC  2348820000000000000  1515970000000000000
# ...                         ...                  ...                  ...
# 208570  2020-05-12 07:16:25 UTC  2353220000000000000  1515970000000000000
# 208571  2020-05-12 07:08:37 UTC  2353220000000000000  1515970000000000000
# 208572  2020-05-12 09:11:47 UTC  2353220000000000000  2273950000000000000
# 208573  2020-05-12 06:43:09 UTC  2353220000000000000  1515970000000000000
# 208574  2020-05-12 06:43:09 UTC  2353220000000000000  1515970000000000000
#
#                category_id                     category_code      brand  \
# ...

# %%
dfx = pd.read_excel('purchase_2.xlsx')

# %%
dfx
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 2        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 3        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 4        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# ...                          ...                  ...                  ...
# 1048570  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223523300096
# 1048571  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1048572  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1048573  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1048574  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
uniq_row=dfx.drop_duplicates()
uniq_row.to_excel('cleaned_file.xlsx', index=False)

# %%
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 2        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 4        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 5        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 6        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1048570  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223523300096
# 1048571  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1048572  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1048573  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1048574  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
duplicate_rows = uniq_row.duplicated(subset=['event_time','order_id'], keep=False)
duplicate_rows
# Out:
# 0          False
# 2          False
# 4          False
# 5          False
# 6          False
#            ...
# 1048570     True
# 1048571    False
# 1048572    False
# 1048573     True
# 1048574     True
# Length: 1036848, dtype: bool

# %% [markdown]
# # Read clean **file**

# %%
dfcf = pd.read_excel('cleaned_file_1.xlsx')
# unique_values_A = dfcf['A'].unique()
dfcf
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036843  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223523300096
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
unique_user_id = dfcf['user_id'].unique()

cnt_unique_user_id = dfcf['user_id'].nunique()
print(cnt_unique_user_id)
# Out:
# 13353

# %%
print(unique_user_id)
# Out:
# [1.51591563e+18 1.51591563e+18 1.51591563e+18 ... 1.51591563e+18
#  1.51591563e+18            nan]

# %%
unique_product_id = dfcf['product_id'].unique()

cnt_product_id = dfcf['product_id'].nunique()
print(cnt_product_id)
# Out:
# 2162

# %%
unique_category_id = dfcf['category_id'].unique()

cnt_category_id = dfcf['category_id'].nunique()
print(cnt_category_id)
# Out:
# 759

# %%
category_starts_with_c = (dfcf['category_code'].str.startswith('e')).sum()


# Display the result
print(category_starts_with_c)
# Out:
# 206685

# %%
category_starts_with_c = (dfcf['category_code'].str.startswith('furniture')).sum()


# Display the result
print(category_starts_with_c)
# Out:
# 49624

# %%
dfcf.describe()
# Out:
#                  order_id          product_id         category_id  price  \
# count             1036848             1036848              846681 846681
# mean  2347996847895822336 1679383533514461440 2274004859827693824    136
# std      5661983296436786  311880752844424320   24040278484266136    216
# min   2294359932054530048 1515966223509080064 2268105388421280000      0
# 25%   2348778846943179776 1515966223509110016 2268105407144649984     14
# 50%   2348798113356964864 1515966223509380096 2268105428166500096     47
# 75%   2348817123372950016 1515966223523300096 2268105441856709888    162
# max   2353219986656330240 2349253022959269888 2374498914001939968  18329
#
#                   user_id
# count              885129
# mean  1515915625558960640
# std              35541669
# min   1515915625353220096
# 25%   1515915625532999936
# 50%   1515915625554080000
# 75%   1515915625594510080
# max   1515915625611020032

# %%
dfcf.dtypes
# Out:
# event_time        object
# order_id           int64
# product_id         int64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# dtype: object

# %%
dfcf.isnull().sum()
# Out:
# event_time            0
# order_id              0
# product_id            0
# category_id      190167
# category_code    258388
# brand            225843
# price            190167
# user_id          151719
# dtype: int64

# %% [markdown]
# # Remove numeric values from category

# %%
# Convert non-numeric values in 'category' column to string
dfcf['category_code'] = dfcf['category_code'].astype(str)

# # Remove rows where 'category' column contains numeric values
non_numeric_df = dfcf[~dfcf['category_code'].str.isnumeric()]

# print("DataFrame after removing rows with numeric values in 'category' column:")
print(non_numeric_df)
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036843  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223523300096
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %% [markdown]
# # Removing numertic columns in category_code column to excel

# %%
non_numeric_df.to_excel('cleaned_file_2.xlsx', index=False)

# %% [markdown]
# # Check 'nan' values in category_code column

# %%
num_other_occurrences = (non_numeric_df['category_code'] == 'nan').sum()

print("Number of occurrences of 'nan' in the 'category' column:", num_other_occurrences)
# Out:
# Number of occurrences of 'nan' in the 'category' column: 258388

# %% [markdown]
# # Assign 'other' value to 'nan' value in category_code

# %%
non_numeric_df.loc[non_numeric_df['category_code'] == 'nan', 'category_code'] = 'other'

print("DataFrame after assigning 'other' to all occurrences of 'nan' in the 'category_code' column:")
print(non_numeric_df)
# Out:
# DataFrame after assigning 'other' to all occurrences of 'nan' in the 'category_code' column:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036843  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223523300096
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# ...

# %% [markdown]
# # Chech NaN values in price column

# %%
num_nan_values = non_numeric_df['price'].isna().sum()

print("Number of NaN values in the 'price' column:", num_nan_values)
# Out:
# Number of NaN values in the 'price' column: 187972

# %% [markdown]
# # Remove NaN values from price column

# %%
rem_nul_price = non_numeric_df[~non_numeric_df['price'].isnull()]
rem_nul_price
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %% [markdown]
# # Removing records that doesn't contain price

# %%
rem_nul_price.to_excel('cleaned_file_3.xlsx', index=False)

# %%
num_nan_values = rem_nul_price['price'].isna().sum()

print("Number of NaN values in the 'price' column:", num_nan_values)
# Out:
# Number of NaN values in the 'price' column: 0

# %% [markdown]
# # Assign 'other' to 'nan' value in category_code (after removing null price)

# %%
rem_nul_price.loc[rem_nul_price['category_code'] == 'nan', 'category_code'] = 'other'

print("DataFrame after assigning 'other' to all occurrences of 'nan' in the 'category_code' column:")
print(rem_nul_price)
# Out:
# DataFrame after assigning 'other' to all occurrences of 'nan' in the 'category_code' column:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# ...

# %% [markdown]
# # Downloading xlxs file of contains category as 'other'

# %%
rem_nul_price.to_excel('cleaned_file_4.xlsx', index=False)

# %%
rem_nul_price.describe()
# Out:
#            order_id    product_id   category_id          price       user_id
# count  8.466810e+05  8.466810e+05  8.466810e+05  846681.000000  7.139580e+05
# mean   2.347806e+18  1.716088e+18  2.274005e+18     136.121358  1.515916e+18
# std    6.230998e+15  3.343223e+17  2.404028e+16     216.080183  3.591099e+07
# min    2.294360e+18  1.515966e+18  2.268105e+18       0.000000  1.515916e+18
# 25%    2.348779e+18  1.515966e+18  2.268105e+18      13.630000  1.515916e+18
# 50%    2.348798e+18  1.515966e+18  2.268105e+18      47.200000  1.515916e+18
# 75%    2.348818e+18  2.273948e+18  2.268105e+18     162.010000  1.515916e+18
# max    2.353220e+18  2.349253e+18  2.374499e+18   18328.680000  1.515916e+18

# %%
rem_nul_price.isnull().sum()
# Out:
# event_time            0
# order_id              0
# product_id            0
# category_id           0
# category_code         0
# brand             41961
# price                 0
# user_id          132723
# dtype: int64

# %% [markdown]
# # remove records where brand name is null

# %%
# Remove rows containing null values in the 'brand' column
rem_nul_brand = rem_nul_price.dropna(subset=['brand'])

print("DataFrame after removing rows with null values in the 'brand' column:")
print(rem_nul_brand)
# Out:
# DataFrame after removing rows with null values in the 'brand' column:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
# ...

# %% [markdown]
# # create xlxs file after removing null value from brand

# %%
rem_nul_brand.to_excel('cleaned_file_5.xlsx', index=False)

# %%
rem_nul_brand.describe()
# Out:
#            order_id    product_id   category_id          price       user_id
# count  8.047200e+05  8.047200e+05  8.047200e+05  804720.000000  6.784020e+05
# mean   2.347795e+18  1.714435e+18  2.273905e+18     140.652221  1.515916e+18
# std    6.265078e+15  3.334294e+17  2.382722e+16     217.335319  3.593741e+07
# min    2.294360e+18  1.515966e+18  2.268105e+18       0.000000  1.515916e+18
# 25%    2.348779e+18  1.515966e+18  2.268105e+18      13.870000  1.515916e+18
# 50%    2.348798e+18  1.515966e+18  2.268105e+18      50.900000  1.515916e+18
# 75%    2.348818e+18  2.273948e+18  2.268105e+18     175.900000  1.515916e+18
# max    2.353220e+18  2.344948e+18  2.374499e+18    9606.480000  1.515916e+18

# %%
rem_nul_brand.isnull().sum()
# Out:
# event_time            0
# order_id              0
# product_id            0
# category_id           0
# category_code         0
# brand                 0
# price                 0
# user_id          126318
# dtype: int64

# %%
rem_nul_brand.dtypes
# Out:
# event_time        object
# order_id           int64
# product_id         int64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# dtype: object

# %% [markdown]
# # how to count column of dtype float64 contains records of other dtype

# %%
count_other_dtype = rem_nul_brand.loc[rem_nul_brand['price'].notnull() & rem_nul_brand['price'].apply(lambda x: not isinstance(x, float)), 'price'].size
print("Number of rows in the 'price' column containing records of other data types:", count_other_dtype)


count_other_dtype = rem_nul_brand.loc[rem_nul_brand['category_id'].notnull() & rem_nul_brand['category_id'].apply(lambda x: not isinstance(x, float)), 'price'].size
print("Number of rows in the 'category_id' column containing records of other data types:", count_other_dtype)


count_other_dtype = rem_nul_brand.loc[rem_nul_brand['user_id'].notnull() & rem_nul_brand['user_id'].apply(lambda x: not isinstance(x, float)), 'price'].size
print("Number of rows in the 'user_id' column containing records of other data types:", count_other_dtype)
# Out:
# Number of rows in the 'price' column containing records of other data types: 0
# Number of rows in the 'price' column containing records of other data types: 0
# Number of rows in the 'price' column containing records of other data types: 0

# %% [markdown]
# # how to count column of dtype object contains records of other dtype

# %%
count_other_dtype = rem_nul_brand.loc[rem_nul_brand['category_code'].apply(lambda x: not isinstance(x, str)), 'category_code'].size
print("Number of rows in the 'category_code' column containing records of other data types:", count_other_dtype)
# Out:
# Number of rows in the 'category_code' column containing records of other data types: 0

# %% [markdown]
# # Count Number of INCONSISTENT records of order_id and event_time

# %%
# Group by order_id and check for inconsistencies
inconsistent_order_ids = []
for order_id, group in rem_nul_brand.groupby('order_id'):
    if group['event_time'].nunique() > 1:
        inconsistent_order_ids.append(order_id)

# Count the number of records with inconsistent event_time
num_inconsistent_records = rem_nul_brand[rem_nul_brand['order_id'].isin(inconsistent_order_ids)].shape[0]

print("Number of records with inconsistent event_time:", num_inconsistent_records)
# Out:
# Number of records with inconsistent event_time: 23414

# %% [markdown]
# # Display inconsistent records

# %%
inconsistent_order_ids = []
for order_id, group in rem_nul_brand.groupby('order_id'):
    if group['event_time'].nunique() > 1:
        inconsistent_order_ids.append(order_id)

# Filter DataFrame to include only rows with inconsistent event_time
inconsistent_rows = rem_nul_brand[rem_nul_brand['order_id'].isin(inconsistent_order_ids)]

print("Rows with inconsistent event_time:")
print(inconsistent_rows)
# Out:
# Rows with inconsistent event_time:
#                      event_time             order_id           product_id  \
# 97129   2020-01-09 12:43:44 UTC  2348767502147780096  1515966223509080064
# 97130   2020-01-09 12:43:44 UTC  2348767502147780096  1515966223509250048
# 97131   2020-01-08 09:57:05 UTC  2348767502147780096  1515966223509120000
# 97208   2020-01-09 07:16:33 UTC  2348767509538140160  2273948303068489984
# 97209   2020-01-08 14:04:05 UTC  2348767509538140160  2273948319115899904
# ...                         ...                  ...                  ...
# 997251  2020-04-26 12:00:00 UTC  2348832886515299840  1515966223509100032
# 997268  2020-04-25 08:24:21 UTC  2348832888973159936  1515966223509080064
# 997269  2020-04-26 02:33:50 UTC  2348832888973159936  1515966223509260032
# 997289  2020-04-25 12:00:00 UTC  2348832890583770112  1515966223509080064
# 997290  2020-04-26 08:32:28 UTC  2348832890583770112  1515966223509080064
#
# ...

# %% [markdown]
# # Removes inconsistent event_time records

# %%
# # Remove records with inconsistent event_time
df_cleaned = rem_nul_brand[~rem_nul_brand['order_id'].isin(inconsistent_order_ids)]
print("DataFrame after removing records with inconsistent event_time:")
print(df_cleaned)
# Out:
# DataFrame after removing records with inconsistent event_time:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.to_excel('cleaned_file_6.xlsx', index=False)

# %%
# Group by order_id and check for inconsistencies
inconsistent_order_ids = []
for order_id, group in df_cleaned.groupby('order_id'):
    if group['event_time'].nunique() > 1:
        inconsistent_order_ids.append(order_id)

# Count the number of records with inconsistent event_time
num_inconsistent_records = df_cleaned[df_cleaned['order_id'].isin(inconsistent_order_ids)].shape[0]

print("Number of records with inconsistent event_time:", num_inconsistent_records)
# Out:
# Number of records with inconsistent event_time: 0

# %% [markdown]
# # Number of Unique customer IDs

# %%
# Assuming you have a DataFrame named 'df' with a column 'user_id'
unique_user_count = len(df_cleaned['user_id'].unique())

# Print or inspect the count of unique users
print(unique_user_count)
# Out:
# 12836

# %%
import pandas as pd
import numpy as np

# Define the range of user IDs
start_user_id = 1591562541901000
end_user_id =   1591562561901000

# Generate 10,000 unique user IDs within the specified range
unique_user_ids = np.random.randint(start_user_id, end_user_id + 1, size=10000)

# Assign user IDs to order IDs such that multiple order IDs have the same user ID
np.random.seed(42)  # For reproducibility
df_cleaned['user_id1'] = np.random.choice(unique_user_ids, size=len(df_cleaned))

print("DataFrame with new column user_id1:")
print(df_cleaned)
# Out:
# DataFrame with new column user_id1:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# event_time            0
# order_id              0
# product_id            0
# category_id           0
# category_code         0
# brand                 0
# price                 0
# user_id          123661
# user_id1              0
# dtype: int64

# %% [markdown]
# # Drop the 'user_id' column

# %%
df_cleaned.drop('user_id', axis=1, inplace=True)

print(df_cleaned)
# Out:
# DataFrame after dropping the 'user_id' column:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %% [markdown]
# # Rename the 'user_id1' column to 'user_id'

# %%
df_cleaned.rename(columns={'user_id1': 'user_id'}, inplace=True)

print(df_cleaned)
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# event_time       0
# order_id         0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# dtype: int64

# %%
df_cleaned.describe()
# Out:
#            order_id    product_id   category_id          price       user_id
# count  7.813060e+05  7.813060e+05  7.813060e+05  781306.000000  7.813060e+05
# mean   2.347765e+18  1.714237e+18  2.273913e+18     140.933676  1.591563e+15
# std    6.355835e+15  3.333219e+17  2.383928e+16     217.777836  5.788315e+06
# min    2.294360e+18  1.515966e+18  2.268105e+18       0.000000  1.591563e+15
# 25%    2.348779e+18  1.515966e+18  2.268105e+18      13.870000  1.591563e+15
# 50%    2.348799e+18  1.515966e+18  2.268105e+18      50.900000  1.591563e+15
# 75%    2.348818e+18  2.273948e+18  2.268105e+18     175.900000  1.591563e+15
# max    2.353220e+18  2.344948e+18  2.374499e+18    9606.480000  1.591563e+15

# %% [markdown]
# # Convert to xlsx file after removing all null values

# %%
df_cleaned.to_excel('cleaned_file_7.xlsx', index=False)

# %% [markdown]
# # Number of Unique User IDs

# %%
unique_user_count = len(df_cleaned['user_id'].unique())

print(unique_user_count)
# Out:
# 9997

# %% [markdown]
# # Create new user_id1 col since last one was not correct

# %%
import pandas as pd
import numpy as np

start_user_id = 911562541901000
end_user_id =   911562561901000
num_unique_user_ids = 10000
unique_user_ids = np.arange(start_user_id, start_user_id + num_unique_user_ids)

# Create a mapping between order_id and user_id1
order_id_to_user_id1 = df_cleaned.drop_duplicates(subset='order_id').assign(user_id1=np.random.choice(unique_user_ids, len(df_cleaned['order_id'].unique()))).set_index('order_id')['user_id1']

# Map order_id to user_id1
df_cleaned['user_id1'] = df_cleaned['order_id'].map(order_id_to_user_id1)

print("DataFrame with new column user_id1:")
print(df_cleaned)
# Out:
# DataFrame with new column user_id1:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.to_excel('cleaned_file_8.xlsx', index=False)

# %%
df_cleaned.drop('user_id', axis=1, inplace=True)

print(df_cleaned)
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.rename(columns={'user_id1': 'user_id'}, inplace=True)

print(df_cleaned)
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054530048  1515966223509080064
# 1        2020-04-24 14:37:43 UTC  2294444024058080000  2273948319057179904
# 2        2020-04-24 19:16:21 UTC  2294584263154070016  2273948316817420032
# 3        2020-04-26 08:45:57 UTC  2295716521449609984  1515966223509260032
# 4        2020-04-26 09:33:47 UTC  2295740594749700096  1515966223509100032
# ...                          ...                  ...                  ...
# 1036842  2020-05-12 07:16:25 UTC  2353219986312390144  1515966223509100032
# 1036844  2020-05-12 07:08:37 UTC  2353219986429830144  1515966223509090048
# 1036845  2020-05-12 09:11:47 UTC  2353219986530500096  2273948222294579968
# 1036846  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223509289984
# 1036847  2020-05-12 06:43:09 UTC  2353219986656330240  1515966223510400000
#
# ...

# %%
df_cleaned.to_excel('cleaned_file_9.xlsx', index=False)

# %% [markdown]
# # Count the number of users in the 'user_id' column

# %%
unique_user_count = len(df_cleaned['user_id'].unique())

print(unique_user_count)
# Out:
# 10000

# %% [markdown]
# # Count the number of rows in the 'category_code' column that start with 'string'

# %%
starts_with_count = df_cleaned[df_cleaned['category_code'].str.startswith('other')].shape[0]

print(starts_with_count)
# Out:
# 229868

# %%
unique_user_count = len(df_cleaned['product_id'].unique())

print(unique_user_count)
# Out:
# 1967

# %%
unique_user_count = len(df_cleaned['category_id'].unique())

print(unique_user_count)
# Out:
# 700

# %%
unique_user_count = len(df_cleaned['order_id'].unique())

print(unique_user_count)
# Out:
# 501351

# %%
unique_user_count = len(df_cleaned['user_id'].unique())

print(unique_user_count)
# Out:
# 10000

# %%
import pandas as pd

df = pd.read_excel('cleaned_file_9.xlsx')

print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-3-357d4d78c463> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel('cleaned_file_9.xlsx')
#       4
#       5 print(df.head(10))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
